# %%
import pandas as pd

df = pd.read_csv("../../data/Fundamental_Downside_Data.csv")
df.head()
# Out:
#                  Name Price/Earnings Industry Avg. (P/E)  \
# 0  Adani Green Energy           815x                 24x
# 1         Adani Power            29x                 24x
# 2     Adani Total Gas           831x                 20x
# 3  Adani Transmission           312x                 24x
# 4   Adani Enterprises           508x                 12x
#
#   Implied Downside (P/E) Price/Sales Industry Avg. (P/S)  \
# 0                -97.10%       60.6x                1.1x
# 1                -18.17%        3.9x                1.1x
# 2                -97.64%      139.3x                1.1x
# 3                -92.43%       27.3x                1.1x
# 4                -97.68%        5.7x                0.5x
#
#   Implied Downside (P/S) EV/EBITDA Industry Avg. (EV/EBITDA)  \
# 0                -98.13%      101x                       12x
# 1                -70.66%       13x                       12x
# 2                -99.31%      303x                        9x
# ...
